# %%
# %matplotlib widget

from PIL import Image
import cv2 
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt

import ipywidgets as widgets
from ipywidgets import interact, HBox

import os
import sys
# sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname(__file__), '..')))
# os.path.abspath(os.path.join('..')
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from cv2 import aruco

# %% [markdown]
# # pose estimate - acc

# %%
import glob, os

acc = []
os.chdir("../res/unit_tests/pose_est/accuracy")
for file in sorted(glob.glob("*"), key=os.path.getmtime):
    acc.append(cv2.imread(file))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,4,1)
ax1.imshow(acc[0])
ax2 = fig.add_subplot(1,4,2)
ax2.imshow(acc[1])
ax3 = fig.add_subplot(1,4,3)
ax3.imshow(acc[2])
ax4 = fig.add_subplot(1,4,4)
ax4.imshow(acc[3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-877021321005> in <module>
#       1 fig = plt.figure()
#       2 ax1 = fig.add_subplot(1,4,1)
# ----> 3 ax1.imshow(acc[0])
#       4 ax2 = fig.add_subplot(1,4,2)
#       5 ax2.imshow(acc[1])
#
# ~/.virtualenvs/cv/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.virtualenvs/cv/lib/python3.6/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
# ...

# %%
f, axarr = plt.subplots(1,4, figsize=(10,10))
axarr[0].imshow(acc[0])
axarr[1].imshow(acc[1])
axarr[2].imshow(acc[2])
axarr[3].imshow(acc[3])

# %% [markdown]
# # pose estimate - brightness

# %%
os.getcwd()

# %%
os.chdir('../../../')

# %%
bright = []
os.chdir("../res/unit_tests/pose_est/brightness")
for file in sorted(glob.glob("*"), key=os.path.getmtime):
    bright.append(cv2.imread(file))

# %%
f, axarr = plt.subplots(1,3, figsize=(10,10))
axarr[0].imshow(bright[0])
axarr[1].imshow(bright[2])
axarr[2].imshow(bright[1])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # pose estimate - interference

# %%
os.getcwd()
# Out:
# '/home/abhi/Code/3D-Scanner/res'

# %%
os.chdir('../../../')

# %%
interference = []
os.chdir("../res/unit_tests/pose_est/interfe")
for file in sorted(glob.glob("*"), key=os.path.getmtime):
    interference.append(cv2.imread(file))

# %%
len(interference)

# %%
f, axarr = plt.subplots(3,3, figsize=(10,10))
axarr[0][0].imshow(interference[0])
axarr[0][1].imshow(interference[1])
axarr[0][2].imshow(interference[3])
axarr[1][0].imshow(interference[2])
axarr[1][1].imshow(interference[6])
axarr[1][2].imshow(interference[7])

axarr[2][0].imshow(interference[4])
axarr[2][1].imshow(interference[5])
axarr[2][2].imshow(interference[8])

# %%
os.chdir('../../../')
os.getcwd()

# %%
laser_acc = []
os.chdir("../res/unit_tests/laser_iso/accuracy")
for file in sorted(glob.glob("*"), key=os.path.getmtime):
    laser_acc.append(cv2.imread(file))

# %%
f, axarr = plt.subplots(1,6, figsize=(15,10))
axarr[0].imshow(laser_acc[4])
axarr[1].imshow(laser_acc[1])
axarr[2].imshow(laser_acc[2])

axarr[3].imshow(laser_acc[3])
axarr[4].imshow(laser_acc[4])
axarr[5].imshow(laser_acc[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-f71df5547ef1> in <module>
#       6 axarr[3].imshow(laser_acc[3])
#       7 axarr[4].imshow(laser_acc[4])
# ----> 8 axarr[5].imshow(laser_acc[5])
#
# IndexError: list index out of range
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
